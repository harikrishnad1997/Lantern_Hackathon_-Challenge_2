# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/fulvestrantTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Fulvestrant_response    type  mut_C1orf222  mut_CAMTA1  \
# Breast_SQ68                      1  Breast             0           0
# Breast_EI813                     0  Breast             0           0
# Breast_PV9                       1  Breast             0           0
# Breast_KY76                      0  Breast             0           0
# Breast_EPQV2                     1  Breast             0           0
#
#               mut_H6PD  mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  \
# Breast_SQ68          0         0          0           0            1
# Breast_EI813         0         0          0           0            0
# Breast_PV9           0         0          1           0            1
# Breast_KY76          0         0          0           0            0
# Breast_EPQV2         0         1          0           1            0
#
#               mut_CSMD2  ...  rna_MAFIP  rna_CD24  rna_HLA-DRB3  \
# Breast_SQ68           0  ...   1.765641  3.610263      0.000000
# Breast_EI813          0  ...   0.683720  1.901263      0.000000
# Breast_PV9            0  ...   2.985080  4.125750      0.160901
# Breast_KY76           0  ...   0.442882  0.320471      0.077141
# Breast_EPQV2          0  ...   3.361561  7.317910      0.071225
#
#               rna_LOC389831  rna_MGC70870  rna_LOC100233156  rna_LOC389834  \
# Breast_SQ68        0.144895      0.109381          0.000000       0.377070
# Breast_EI813       1.973497      0.560144          0.763473       0.508316
# Breast_PV9         1.316661      0.265797          1.167377       1.316250
# Breast_KY76        3.301013      0.063881          0.323250       0.515944
# Breast_EPQV2       2.624524      0.108735          1.402040       1.296005
#
#               rna_LOC283788  rna_RNA5-8S5  rna_LOC102723780
# Breast_SQ68        0.743830      7.430427          0.379076
# Breast_EI813       1.166169      9.509599          1.445901
# Breast_PV9         1.320358      7.672418          0.230426
# Breast_KY76        0.272920      4.727648          0.222489
# Breast_EPQV2       1.550906     10.491553          2.474496
#
# [5 rows x 15990 columns]

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Fulvestrant_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 1602

# %%
Fulvestrant_df = df[final_columns]

# %%
# Assuming 'y' is the response column
Fulvestrant_df  = Fulvestrant_df [[col for col in Fulvestrant_df .columns if col != 'Fulvestrant_response'] + ['Fulvestrant_response']]

# %%
Fulvestrant_df.head()
# Out:
#               rna_RPS8  rna_JAG2  rna_FAM117A  rna_PARVA  rna_NPIPB8  \
# Breast_SQ68   8.187060  1.118021     0.142697   0.470426    0.458195
# Breast_EI813  8.310345  0.136925     0.686193   2.742539    0.365429
# Breast_PV9    9.275377  1.664665     2.660719   0.696842    1.204059
# Breast_KY76   9.909452  0.034321     0.531669   3.227733    0.186809
# Breast_EPQV2  9.374633  1.859389     3.111357   1.450200    1.402466
#
#               rna_ZNHIT3  rna_TEAD1  rna_LOC105377348  rna_TRAPPC5  \
# Breast_SQ68     3.015783   1.889435          0.363915     5.714361
# Breast_EI813    2.756325   2.464606          0.441140     5.292358
# Breast_PV9      4.439124   1.462241          1.225071     5.941505
# Breast_KY76     5.096393   3.623282          1.188110     3.731118
# Breast_EPQV2    5.264679   2.030068          0.634392     5.644361
#
#               rna_LOC341056  ...  rna_PSMG4  rna_ASB9   rna_EFS  rna_C14orf1  \
# Breast_SQ68        1.431013  ...   5.015774  0.269122  0.120039     3.597829
# Breast_EI813       0.787966  ...   3.712123  0.000000  1.202399     3.013861
# Breast_PV9         1.171393  ...   4.289119  0.000000  1.679699     4.206456
# Breast_KY76        0.324944  ...   6.498677  1.209734  0.034199     2.878802
# Breast_EPQV2       0.649334  ...   3.690674  0.061061  2.734829     5.129464
#
#               rna_DCAF4  rna_OR51I2  rna_CNTROB  rna_NXNL2  rna_SLC2A1  \
# Breast_SQ68    2.058542         0.0    1.966039   1.950282    2.076289
# Breast_EI813   1.119084         0.0    1.567750   0.397251    4.638769
# Breast_PV9     2.639526         0.0    1.739295   0.759074    4.156510
# Breast_KY76    2.214268         0.0    0.638701   0.186315    3.816036
# Breast_EPQV2   1.667765         0.0    1.472545   0.804028    2.286837
#
#               Fulvestrant_response
# Breast_SQ68                      1
# Breast_EI813                     0
# Breast_PV9                       1
# Breast_KY76                      0
# Breast_EPQV2                     1
#
# [5 rows x 1602 columns]

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Fulvestrant_final.csv', index=False)
