# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/gefitinibTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Gefitinib_response    type  mut_C1orf222  mut_CAMTA1  mut_H6PD  \
# Breast_SQ68                    0  Breast             0           0         0
# Breast_EI813                   0  Breast             0           0         0
# Breast_PV9                     0  Breast             0           0         0
# Breast_KY76                    0  Breast             0           0         0
# Breast_EPQV2                   0  Breast             0           0         0
#
#               mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  mut_CSMD2  ...  \
# Breast_SQ68          0          0           0            1          0  ...
# Breast_EI813         0          0           0            0          0  ...
# Breast_PV9           0          1           0            1          0  ...
# Breast_KY76          0          0           0            0          0  ...
# Breast_EPQV2         1          0           1            0          0  ...
#
#               rna_MAFIP  rna_CD24  rna_HLA-DRB3  rna_LOC389831  rna_MGC70870  \
# Breast_SQ68    1.765641  3.610263      0.000000       0.144895      0.109381
# Breast_EI813   0.683720  1.901263      0.000000       1.973497      0.560144
# Breast_PV9     2.985080  4.125750      0.160901       1.316661      0.265797
# Breast_KY76    0.442882  0.320471      0.077141       3.301013      0.063881
# Breast_EPQV2   3.361561  7.317910      0.071225       2.624524      0.108735
#
#               rna_LOC100233156  rna_LOC389834  rna_LOC283788  rna_RNA5-8S5  \
# Breast_SQ68           0.000000       0.377070       0.743830      7.430427
# Breast_EI813          0.763473       0.508316       1.166169      9.509599
# Breast_PV9            1.167377       1.316250       1.320358      7.672418
# Breast_KY76           0.323250       0.515944       0.272920      4.727648
# Breast_EPQV2          1.402040       1.296005       1.550906     10.491553
#
#               rna_LOC102723780
# Breast_SQ68           0.379076
# Breast_EI813          1.445901
# Breast_PV9            0.230426
# Breast_KY76           0.222489
# Breast_EPQV2          2.474496
#
# [5 rows x 15990 columns]

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Gefitinib_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 837

# %%
final_columns
# Out:
# ['rna_PSMD8',
#  'rna_C5orf30',
#  'rna_CNOT10',
#  'rna_ZNF184',
#  'rna_DLSTP1',
#  'rna_SNORA26',
#  'rna_ANKRD52',
#  'rna_MCTP1',
#  'rna_FAM25A',
#  'rna_SLC1A5',
#  'rna_RPL13AP3',
#  'rna_PIH1D1',
#  'rna_RSRP1',
#  'rna_KIFC3',
#  'rna_TES',
#  'rna_TMEM147',
#  'rna_NPFFR2',
#  'rna_CES2',
#  'rna_ABCB7',
#  'rna_RPS18P9',
#  'rna_PPP1R3G',
#  'rna_KLF11',
#  'rna_SUCLG2-AS1',
#  'rna_ACYP1',
#  'rna_RPSA',
#  'rna_C11orf95',
#  'rna_HES4',
#  'rna_BAIAP2L1',
#  'rna_CHST9',
#  'rna_LRRC16A',
#  'rna_TBCB',
#  'rna_RNF5P1',
#  'rna_CELF1',
#  'rna_RUFY1',
#  'rna_ADCY9',
#  'rna_FOXH1',
#  'rna_HSCB',
#  'rna_PUSL1',
#  'rna_FURIN',
#  'rna_PURA',
#  'rna_PLAC8L1',
#  'rna_GLO1',
#  'rna_SMIM6',
#  'rna_ISOC1',
#  'rna_SIRPA',
#  'rna_ATXN3',
#  'rna_RNF168',
#  'rna_HMGN4',
#  'rna_C1orf21',
#  'rna_TPM2',
#  'mut_CHI3L2',
#  'rna_YPEL1',
#  'rna_ITPR3',
#  'rna_FLJ44635',
#  'rna_RIPK4',
#  'rna_PSMG1',
#  'rna_SYTL2',
#  'rna_PWWP2A',
#  'rna_RNF7',
#  'rna_UQCR10',
#  'rna_NACA2',
#  'rna_RPS15AP10',
#  'rna_C5orf66',
#  'rna_TGM2',
#  'rna_SYT16',
#  'rna_GLRX2',
#  'rna_SRA1',
#  'rna_NDUFA8',
#  'rna_POP4',
#  'rna_MRPS31',
#  'rna_STRA13',
#  'rna_CAMLG',
#  'rna_RNF213',
#  'rna_ZDHHC4',
#  'rna_PCNXL2',
#  'rna_EVC',
#  'rna_THBD',
#  'rna_UBA2',
#  'rna_TTC28-AS1',
#  'rna_DCDC2',
#  'rna_ETF1',
#  'rna_LOC441454',
#  'rna_EXOC6B',
#  'rna_GNB2L1',
#  'rna_LINC01504',
#  'rna_VCAN',
#  'rna_ACOT13',
#  'rna_EPB41L4A-AS1',
#  'rna_NDUFS5',
#  'rna_STX11',
#  'rna_FAM76A',
#  'rna_RHOBTB2',
#  'rna_GLS',
#  'rna_ZNF346',
#  'rna_ZNF131',
#  'rna_FAM49A',
#  'rna_SKP1',
#  'rna_MMP28',
#  'rna_EIF3H',
#  'rna_SHISA9',
#  'rna_KCCAT198',
#  'rna_NAA38',
#  'rna_FBXO33',
#  'rna_SIAH2',
#  'rna_TUBB4A',
#  'rna_LOC101929767',
#  'rna_SYF2',
#  'rna_NACAP1',
#  'rna_RABEPK',
#  'rna_ATP8B3',
#  'rna_LOC284023',
#  'rna_SSSCA1',
#  'rna_PPP1R9A',
#  'rna_KCNK3',
#  'rna_TAF11',
#  'rna_PVT1',
#  'rna_BCAS2',
#  'rna_SPP1',
#  'rna_FAAP20',
#  'rna_NACC2',
#  'rna_PPP2CA',
#  'rna_ZNF593',
#  'rna_WRB',
#  'rna_SLC25A5',
#  'rna_RPL39',
#  'rna_FBL',
#  'rna_ZNF180',
#  'rna_CLK4',
#  'rna_SLC22A3',
#  'rna_COA1',
#  'rna_RPL35A',
#  'rna_PDZK1IP1',
#  'rna_ZNF286B',
#  'rna_NOP16',
#  'rna_NPC1',
#  'rna_MTF2',
#  'rna_TAF12',
#  'rna_NHS',
#  'rna_KANK1',
#  'rna_TMEM80',
#  'rna_EIF2AK4',
#  'rna_RSBN1',
#  'rna_MYO18A',
#  'rna_POLR2H',
#  'rna_PRKAA2',
#  'rna_UPF3B',
#  'rna_FAM19A3',
#  'rna_UTRN',
#  'rna_DMTN',
#  'rna_MRFAP1',
#  'rna_RPL30',
#  'rna_ALDH9A1',
#  'rna_ZNF565',
#  'rna_MRPL52',
#  'rna_RASAL2',
#  'rna_TIMD4',
#  'rna_NAT16',
#  'rna_COX8A',
#  'rna_ZC3H12C',
#  'rna_PTPRM',
#  'rna_ETFB',
#  'rna_WNT7B',
#  'rna_COMMD5',
#  'rna_COL9A2',
#  'rna_RPL36A-HNRNPH2',
#  'rna_UIMC1',
#  'rna_SPATA18',
#  'rna_HAS3',
#  'rna_PRR4',
#  'rna_KIRREL',
#  'rna_KIF21A',
#  'rna_ZNF324',
#  'rna_NEFM',
#  'rna_PIGL',
#  'rna_LOC728554',
#  'rna_ARFGEF2',
#  'rna_ANKRD29',
#  'mut_OR5L2',
#  'rna_SEH1L',
#  'rna_ENTPD7',
#  'rna_LOC101927412',
#  'rna_MVP',
#  'rna_NKAP',
#  'rna_RPS20',
#  'rna_TMEM63C',
#  'rna_LIN37',
#  'rna_RHBDF2',
#  'rna_DAP3',
#  'rna_PPIAL4G',
#  'rna_RPL8',
#  'rna_BMP2',
#  'rna_AHNAK',
#  'rna_DEDD2',
#  'rna_HIST1H4C',
#  'rna_THOC3',
#  'rna_CERS6-AS1',
#  'rna_HDAC3',
#  'rna_ZNF844',
#  'rna_HNRNPA0',
#  'rna_LINC01515',
#  'rna_SNHG3',
#  'rna_CD276',
#  'rna_RPL23P8',
#  'rna_PNRC2',
#  'rna_RPS14P3',
#  'rna_MYOF',
#  'rna_RPL34',
#  'rna_FOXP4-AS1',
#  'rna_FBXO45',
#  'rna_TTC39B',
#  'rna_C6orf203',
#  'rna_SMIM3',
#  'rna_NEU3',
#  'rna_SAP18',
#  'rna_ZNF70',
#  'rna_EPHA1',
#  'rna_KIAA0754',
#  'rna_CDC25C',
#  'rna_FAM231D',
#  'rna_SCIN',
#  'rna_ATP5L2',
#  'rna_LOC283352',
#  'rna_ELFN2',
#  'rna_CHST3',
#  'rna_CHURC1',
#  'rna_BOD1',
#  'rna_SIVA1',
#  'rna_LRRC29',
#  'rna_ZFP36L2',
#  'rna_LYRM7',
#  'rna_ZSCAN16',
#  'rna_HOXA1',
#  'rna_CDH5',
#  'rna_FARP2',
#  'rna_TLR6',
#  'rna_TPCN1',
#  'rna_SHISA3',
#  'rna_LPCAT1',
#  'rna_CNOT8',
#  'rna_RPL22',
#  'rna_GLRX5',
#  'rna_HAVCR1',
#  'rna_NSMCE2',
#  'rna_DCAF12L1',
#  'rna_RALB',
#  'rna_AIMP2',
#  'rna_DSTYK',
#  'rna_SNORA76C',
#  'rna_C1orf109',
#  'rna_ZNF252P',
#  'rna_TNFAIP6',
#  'rna_SRSF6',
#  'rna_MGLL',
#  'rna_CCZ1B',
#  'rna_PRTG',
#  'rna_ZNF788',
#  'rna_NQO2',
#  'rna_B3GALT1',
#  'rna_ACAA1',
#  'rna_CYCS',
#  'rna_PTPRS',
#  'rna_CCZ1',
#  'rna_GTF3A',
#  'rna_NHP2',
#  'rna_AP2S1',
#  'rna_HOXD-AS2',
#  'rna_FRA10AC1',
#  'rna_DOCK4',
#  'rna_PRRG1',
#  'rna_RPS4X',
#  'rna_NABP1',
#  'rna_SYT14',
#  'rna_LAGE3',
#  'rna_YY1',
#  'rna_SLAMF7',
#  'rna_SKP1P2',
#  'rna_BCL9',
#  'rna_FGD4',
#  'rna_XAGE1B',
#  'rna_SUCLG1',
#  'rna_PDXK',
#  'rna_TMEM56',
#  'rna_KCNH1',
#  'rna_PTPN2',
#  'mut_ALMS1',
#  'rna_RBPMS',
#  'rna_IGFBP2',
#  'rna_MX2',
#  'rna_POLR2D',
#  'rna_MRPL11',
#  'rna_DNAJA1',
#  'rna_TMEM70',
#  'rna_NKX2-4',
#  'rna_TSEN15',
#  'rna_SAP30L',
#  'mut_XIRP1',
#  'rna_RPL5',
#  'rna_THG1L',
#  'rna_RPS11',
#  'rna_CEBPG',
#  'rna_DANCR',
#  'rna_LOC388282',
#  'rna_FRMD4B',
#  'rna_H2AFY',
#  'rna_PRELID2',
#  'rna_SRP19',
#  'rna_SAR1B',
#  'rna_RPTOR',
#  'rna_RPA3',
#  'rna_TBCC',
#  'rna_LOC341056',
#  'rna_CSNK1G3',
#  'rna_HINT1',
#  'rna_TMPPE',
#  'rna_TIMP2',
#  'rna_EMC9',
#  'rna_SERTAD1',
#  'rna_RPS9',
#  'rna_SUZ12P1',
#  'rna_RPL15',
#  'rna_TATDN1',
#  'rna_TRAPPC3',
#  'rna_PON2',
#  'rna_MRPS17',
#  'rna_SPESP1',
#  'rna_HNF1B',
#  'rna_RP9',
#  'rna_RPL11',
#  'rna_MRPL57',
#  'rna_COMMD6',
#  'rna_BRK1',
#  'rna_GAL3ST1',
#  'rna_CAMTA1',
#  'rna_GTPBP8',
#  'rna_CELSR1',
#  'rna_ADGRG2',
#  'rna_FYCO1',
#  'rna_ATP5EP2',
#  'rna_ARHGAP42',
#  'rna_CAV2',
#  'rna_SNRPD3',
#  'rna_FTX',
#  'rna_PAIP2',
#  'rna_NTMT1',
#  'rna_CADPS2',
#  'rna_SERBP1',
#  'rna_LINC00472',
#  'rna_IPO11-LRRC70',
#  'rna_LOC100506100',
#  'rna_ZNF607',
#  'rna_HNRNPAB',
#  'rna_EXOSC5',
#  'rna_ARGLU1',
#  'rna_CPNE8',
#  'rna_RPL18',
#  'rna_NFKBIB',
#  'rna_RPL35',
#  'rna_MRPL20',
#  'rna_TRNAU1AP',
#  'rna_CA9',
#  'rna_SMURF1',
#  'rna_COX6A1',
#  'rna_RPL13AP20',
#  'rna_MEAT6',
#  'rna_PARK7',
#  'rna_TMEM160',
#  'rna_RRAD',
#  'rna_RPS10',
#  'rna_RAB36',
#  'rna_MINOS1',
#  'rna_DNAJC8',
#  'rna_SNRPD2',
#  'rna_MAT2B',
#  'rna_LOC643387',
#  'rna_UGT2B7',
#  'rna_PAPD7',
#  'rna_SLU7',
#  'rna_SDR42E1',
#  'Gefitinib_response',
#  'rna_PAX8',
#  'rna_KCP',
#  'rna_UQCRB',
#  'rna_NDUFB4',
#  'rna_RER1',
#  'rna_DOCK5',
#  'rna_MECR',
#  'rna_MITF',
#  'rna_RPL14',
#  'rna_RSPO1',
#  'rna_DCAF12L2',
#  'rna_ZNF585A',
#  'rna_BCHE',
#  'rna_FHOD3',
#  'rna_HIGD2A',
#  'rna_MAGEA10',
#  'rna_HOGA1',
#  'rna_FAM53C',
#  'rna_FYTTD1',
#  'rna_XXYLT1',
#  'rna_RBKS',
#  'rna_UQCRQ',
#  'rna_RNU11',
#  'rna_SLC16A8',
#  'rna_NDUFA2',
#  'rna_CD109',
#  'rna_RPP40',
#  'rna_NDUFB11',
#  'rna_SNPH',
#  'rna_NETO2',
#  'rna_SCAMP1',
#  'rna_TOP1P1',
#  'rna_DCP2',
#  'rna_CNDP2',
#  'rna_CDK11B',
#  'rna_CDCA7L',
#  'rna_S100A3',
#  'rna_SRSF10',
#  'rna_CCER2',
#  'rna_GULP1',
#  'rna_OIP5',
#  'rna_DHRS4L1',
#  'rna_GEMIN7',
#  'rna_ANAPC11',
#  'rna_KIZ',
#  'rna_SURF2',
#  'rna_TNFRSF19',
#  'rna_ZNF503-AS2',
#  'rna_CPED1',
#  'rna_TMEM258',
#  'rna_YARS',
#  'rna_LAMA3',
#  'rna_MRPL47',
#  'rna_RNF181',
#  'rna_RPS16',
#  'rna_PGAM4',
#  'rna_RUSC2',
#  'rna_GRID1',
#  'rna_UBE2D2',
#  'rna_NXT1',
#  'rna_FAM162A',
#  'rna_MEST',
#  'rna_TLR3',
#  'rna_MIOX',
#  'rna_UBE2V2',
#  'rna_TCEB1',
#  'rna_PFDN1',
#  'rna_SPTBN1',
#  'rna_UQCRFS1',
#  'rna_CCDC34',
#  'rna_ADAMTS9',
#  'rna_PRMT5-AS1',
#  'rna_RBM22',
#  'rna_TRMT5',
#  'rna_SNHG12',
#  'rna_MRPL2',
#  'rna_CHRAC1',
#  'rna_ALPP',
#  'rna_GALNT2',
#  'rna_ISLR',
#  'rna_TIMM8B',
#  'rna_FMNL2',
#  'rna_RPS23',
#  'rna_LINC00240',
#  'rna_YOD1',
#  'rna_GBGT1',
#  'rna_KLHDC3',
#  'rna_ADGRG6',
#  'rna_SVBP',
#  'rna_GATA2',
#  'rna_AVEN',
#  'rna_FRAT2',
#  'rna_ATP10D',
#  'rna_TAGLN3',
#  'rna_TDG',
#  'rna_LYRM4',
#  'rna_GTF2IP1',
#  'rna_FUNDC2',
#  'rna_FOXP2',
#  'rna_UQCC3',
#  'rna_MRPS14',
#  'rna_NUDCD2',
#  'rna_ELL3',
#  'rna_NFKBIZ',
#  'rna_HMGN1',
#  'rna_FGF14',
#  'rna_WWTR1',
#  'rna_MSI1',
#  'rna_NASP',
#  'rna_APOBEC3C',
#  'rna_SLC35F6',
#  'rna_UXS1',
#  'rna_ZNF383',
#  'rna_CANX',
#  'rna_MFAP3',
#  'rna_ACVR2A',
#  'rna_SEMA4F',
#  'rna_TRAPPC2B',
#  'rna_TAF7',
#  'rna_ABTB2',
#  'rna_AFAP1L2',
#  'rna_VBP1',
#  'rna_SRGAP1',
#  'rna_SLC16A4',
#  'rna_MMP24',
#  'rna_WNT2B',
#  'rna_MRPS22',
#  'rna_KLHDC7A',
#  'rna_GNPTAB',
#  'rna_HYPK',
#  'rna_BRD8',
#  'rna_RPL28',
#  'rna_SGCE',
#  'rna_CHTOP',
#  'rna_PCDHAC1',
#  'rna_ACSL1',
#  'rna_DAPK1',
#  'rna_SSH1',
#  'rna_ATPIF1',
#  'rna_RPL26',
#  'rna_PSMG4',
#  'rna_LOC613038',
#  'rna_SPECC1',
#  'rna_LHX1',
#  'rna_NOL7',
#  'rna_GRPEL2',
#  'rna_ZNF646',
#  'rna_PTDSS1',
#  'rna_SLC26A2',
#  'rna_SRR',
#  'rna_HMGN2P46',
#  'rna_PPP1R16A',
#  'rna_C1orf52',
#  'rna_HILPDA',
#  'rna_MKRN9P',
#  'rna_TIMM9',
#  'rna_DPP9',
#  'rna_POLR2G',
#  'rna_LRRN4',
#  'rna_TRIM52-AS1',
#  'rna_H2AFX',
#  'rna_HOXA3',
#  'rna_HSPA9',
#  'rna_CDKL1',
#  'rna_GPR37',
#  'rna_ANKRD18B',
#  'rna_HIPK2',
#  'rna_MAP3K9',
#  'rna_HNRNPUL2-BSCL2',
#  'rna_ZCCHC10',
#  'rna_ZC3H7B',
#  'rna_COX6B1',
#  'rna_RPAIN',
#  'rna_ING1',
#  'rna_TIMM10',
#  'rna_METRNL',
#  'rna_SARS',
#  'rna_H2AFV',
#  'rna_LINC01111',
#  'rna_PCDHGB5',
#  'rna_CARKD',
#  'rna_OXSR1',
#  'rna_GOT1',
#  'rna_DKC1',
#  'rna_POLR2I',
#  'rna_ANKRD19P',
#  'rna_TMEM41B',
#  'rna_SEC22A',
#  'rna_HINFP',
#  'rna_F2RL3',
#  'rna_PPP2R3C',
#  'rna_MRPL32',
#  'rna_CPEB2',
#  'rna_SREBF1',
#  'rna_LMO7-AS1',
#  'rna_IFITM1',
#  'rna_LINC00515',
#  'rna_ANKHD1',
#  'rna_SCARNA13',
#  'rna_ALDH3B1',
#  'rna_DBNDD2',
#  'rna_FOXN3',
#  'rna_MYO1E',
#  'rna_PPTC7',
#  'rna_RBMXL1',
#  'rna_ZNF211',
#  'rna_HIST1H1A',
#  'rna_SLC17A3',
#  'rna_RPL27A',
#  'rna_CLEC16A',
#  'rna_SRSF2',
#  'rna_UQCRHL',
#  'rna_MXD3',
#  'rna_SNORA80B',
#  'rna_TICAM1',
#  'rna_ARID3B',
#  'rna_RHOBTB1',
#  'rna_LRP3',
#  'rna_CENPV',
#  'rna_VPS51',
#  'rna_NLGN1',
#  'rna_FBXL12',
#  'rna_PLAC8',
#  'rna_ECH1',
#  'rna_ZNF613',
#  'rna_CA3-AS1',
#  'rna_MRPL16',
#  'rna_KIF12',
#  'rna_NCEH1',
#  'rna_SFXN3',
#  'rna_SEC31B',
#  'rna_ETV3',
#  'rna_PDZD11',
#  'rna_ZNF671',
#  'rna_LIMK1',
#  'rna_URI1',
#  'rna_FAM193B',
#  'rna_SLC25A28',
#  'rna_HSD17B10',
#  'rna_PDE7A',
#  'rna_RPSAP9',
#  'rna_KAAG1',
#  'rna_TPK1',
#  'rna_CDK11A',
#  'rna_NNAT',
#  'rna_C15orf61',
#  'rna_SNX9',
#  'rna_XAGE1E',
#  'rna_MRPS12',
#  'rna_IGIP',
#  'rna_TSEN34',
#  'rna_PUS3',
#  'rna_RPS10P7',
#  'rna_GPRC5B',
#  'rna_LOC100288123',
#  'rna_SNRPC',
#  'rna_AFAP1L1',
#  'rna_SLC25A38',
#  'type',
#  'rna_RGMB',
#  'rna_RPSAP58',
#  'rna_LOC101243545',
#  'rna_CNOT6',
#  'rna_PTGIS',
#  'rna_NDUFA6',
#  'rna_QRFPR',
#  'rna_MTCH1',
#  'rna_LOC101928530',
#  'rna_HARS2',
#  'rna_FANK1',
#  'rna_BICC1',
#  'rna_CLDN16',
#  'rna_SUMO1P3',
#  'rna_C8orf76',
#  'rna_NKAIN4',
#  'rna_ITGB3',
#  'rna_PFKFB2',
#  'rna_JUND',
#  'rna_UQCC2',
#  'rna_NCALD',
#  'rna_WNT7A',
#  'rna_TENM2',
#  'rna_ZNF181',
#  'rna_APOM',
#  'rna_LRRC47',
#  'mut_SCRN3',
#  'rna_ADCY6',
#  'rna_RPL10A',
#  'rna_TTC1',
#  'rna_EXOSC3',
#  'rna_SLC7A4',
#  'rna_HSPA12A',
#  'rna_ZHX1-C8orf76',
#  'rna_RPL32',
#  'rna_LOC101929128',
#  'rna_SGSH',
#  'rna_C19orf71',
#  'rna_PAFAH1B3',
#  'rna_SMIM13',
#  'rna_ADAMTS3',
#  'rna_SMCO4',
#  'rna_LINC00958',
#  'rna_PHYKPL',
#  'rna_C7orf61',
#  'rna_MRPS24',
#  'rna_ITPRIPL2',
#  'rna_ANXA4',
#  'rna_FARS2',
#  'rna_TMEM9B',
#  'rna_MEA1',
#  'rna_TMEM178B',
#  'rna_SNX33',
#  'rna_COX7B',
#  'rna_ZNF573',
#  'rna_RPL19P12',
#  'rna_AGAP1',
#  'rna_WNT9A',
#  'rna_NEDD4L',
#  'rna_CTTNBP2',
#  'rna_RPL13AP6',
#  'rna_NDUFS6',
#  'rna_RAB11FIP5',
#  'rna_DEK',
#  'rna_MZT2B',
#  'rna_SAYSD1',
#  'rna_RPS19',
#  'rna_BMP8B',
#  'rna_MFGE8',
#  'rna_AAMDC',
#  'rna_COA4',
#  'rna_C8orf82',
#  'rna_ULBP3',
#  'rna_C6orf99',
#  'rna_SLC22A23',
#  'rna_HDAC1',
#  'rna_RPP21',
#  'rna_VPS53',
#  'rna_PEG10',
#  'rna_SLC38A7',
#  'rna_KIAA0141',
#  'rna_FAAP24',
#  'rna_RELN',
#  'rna_PTPN14',
#  'rna_SLC35F5',
#  'rna_MAL',
#  'rna_N4BP2L2',
#  'rna_CDH16',
#  'rna_EDA2R',
#  'rna_C1orf116',
#  'rna_TRPM8',
#  'rna_PTP4A2',
#  'rna_PCK2',
#  'rna_C1orf186',
#  'rna_AHNAK2',
#  'rna_MRPL43',
#  'rna_NDUFB9',
#  'rna_ZBED5',
#  'rna_SNORA62',
#  'rna_AGMAT',
#  'rna_PAF1',
#  'rna_SNORA80A',
#  'rna_SHTN1',
#  'rna_TOMM6',
#  'rna_RBM4B',
#  'rna_ROR2',
#  'rna_FBXO9',
#  'rna_SPTB',
#  'rna_EIF4EBP3',
#  'rna_DDX46',
#  'rna_KIAA0513',
#  'rna_MCM3',
#  'rna_PLEKHH2',
#  'rna_PCDHB14',
#  'rna_IQCG',
#  'rna_PLCXD3',
#  'rna_CPPED1',
#  'rna_UQCRBP1',
#  'rna_PRELID1',
#  'rna_GREB1L',
#  'rna_FOXE1',
#  'rna_CMBL',
#  'rna_LSM14A',
#  'rna_TSPAN1',
#  'rna_HMGN2',
#  'rna_ZNF251',
#  'rna_ACSL5',
#  'rna_LRIG1',
#  'rna_GPATCH1',
#  'rna_MICAL3',
#  'rna_EEF1D',
#  'rna_CLEC2D',
#  'rna_TMED10',
#  'rna_MRPL14',
#  'rna_CCDC167',
#  'rna_HADH',
#  'rna_ADAP2',
#  'rna_LINC01589',
#  'rna_UBE2B',
#  'rna_LOC388242',
#  'rna_ZNF22',
#  'rna_EIF2B2',
#  'rna_RPL13A',
#  'rna_CEP250',
#  'rna_IQCK',
#  'rna_HHAT',
#  'rna_C1QBP',
#  'rna_ZNF585B',
#  'rna_KIF16B',
#  'rna_GPAT3',
#  'rna_DPH3',
#  'rna_ELOVL2',
#  'rna_PGBD3',
#  'rna_SDHAP2',
#  'rna_CFL1',
#  'rna_MYO10',
#  'rna_CNBP',
#  'rna_FAU',
#  'rna_YWHAE',
#  'rna_CYP7B1',
#  'rna_WT1',
#  'rna_RNASEH2C',
#  'rna_LARS',
#  'rna_FBXO46',
#  'rna_CHCHD7',
#  'rna_GMEB1',
#  'rna_BMP6',
#  'rna_WDYHV1',
#  'rna_TNS3',
#  'rna_LINC00941',
#  'rna_EIF3K',
#  'rna_MDFIC',
#  'rna_IGF2R',
#  'rna_NUFIP1',
#  'rna_AK2',
#  'rna_SNORA18',
#  'rna_B9D2',
#  'rna_RAB24',
#  'rna_TMEM216',
#  'rna_RPL36A',
#  'rna_ZMAT2',
#  'rna_FAM104B',
#  'rna_MRPL22',
#  'rna_IK',
#  'rna_MED19',
#  'rna_FGB',
#  'rna_PIN4',
#  'rna_ZBED2',
#  'rna_PAX2',
#  'rna_UTP23',
#  'rna_SORBS3',
#  'rna_ZNF319',
#  'rna_TNFSF9',
#  'rna_DSCC1',
#  'rna_KCNJ6',
#  'rna_CRYBG3',
#  'rna_RAB11FIP1',
#  'rna_SYCE1L',
#  'rna_EDEM2']

# %%
Gefitinib_df = df[final_columns]

# %%
Gefitinib_df.head()
# Out:
#               rna_PSMD8  rna_C5orf30  rna_CNOT10  rna_ZNF184  rna_DLSTP1  \
# Breast_SQ68    5.231459     2.216166    1.818478    1.219141    1.186127
# Breast_EI813   5.249426     1.690319    1.085037    0.887810    0.663223
# Breast_PV9     5.176945     2.272008    2.221153    1.484391    1.758376
# Breast_KY76    5.154024     1.870811    2.459471    2.132672    0.494807
# Breast_EPQV2   5.456271     1.529701    2.724480    1.190476    1.196683
#
#               rna_SNORA26  rna_ANKRD52  rna_MCTP1  rna_FAM25A  rna_SLC1A5  \
# Breast_SQ68           0.0     2.043649   0.748235    0.000000    6.246001
# Breast_EI813          0.0     2.604800   0.084083    0.000000    6.220761
# Breast_PV9            0.0     2.951661   0.203724    0.000000    4.953871
# Breast_KY76           0.0     0.681669   1.280838    0.000000    3.253469
# Breast_EPQV2          0.0     3.353398   0.126857    2.249363    4.996285
#
#               ...  rna_UTP23  rna_SORBS3  rna_ZNF319  rna_TNFSF9  rna_DSCC1  \
# Breast_SQ68   ...   2.091050    5.444250    0.735619    3.384775   1.780470
# Breast_EI813  ...   1.413437    4.977903    0.779594    1.501847   1.510213
# Breast_PV9    ...   1.675468    2.568852    0.403705    0.382281   1.929621
# Breast_KY76   ...   2.767691    0.486446    0.243271    0.748612   3.508708
# Breast_EPQV2  ...   2.114347    3.199105    0.718491    0.773509   1.567253
#
#               rna_KCNJ6  rna_CRYBG3  rna_RAB11FIP1  rna_SYCE1L  rna_EDEM2
# Breast_SQ68    0.000000    0.383234       0.929657    0.323235   3.361120
# Breast_EI813   0.088314    0.568509       1.439932    0.000000   2.401581
# Breast_PV9     0.000000    0.045102       1.801183    0.000000   2.263509
# Breast_KY76    0.000000    0.868706       1.435175    0.000000   0.654121
# Breast_EPQV2   0.044568    0.838878       3.258475    0.000000   2.568485
#
# [5 rows x 837 columns]

# %%
# Assuming 'y' is the response column
Gefitinib_df = Gefitinib_df[[col for col in Gefitinib_df.columns if col != 'Gefitinib_response'] + ['Gefitinib_response']]

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Gefitinib_final.csv', index=False)

# %%
Gefitinib_df.head()
# Out:
#               rna_PSMD8  rna_C5orf30  rna_CNOT10  rna_ZNF184  rna_DLSTP1  \
# Breast_SQ68    5.231459     2.216166    1.818478    1.219141    1.186127
# Breast_EI813   5.249426     1.690319    1.085037    0.887810    0.663223
# Breast_PV9     5.176945     2.272008    2.221153    1.484391    1.758376
# Breast_KY76    5.154024     1.870811    2.459471    2.132672    0.494807
# Breast_EPQV2   5.456271     1.529701    2.724480    1.190476    1.196683
#
#               rna_SNORA26  rna_ANKRD52  rna_MCTP1  rna_FAM25A  rna_SLC1A5  \
# Breast_SQ68           0.0     2.043649   0.748235    0.000000    6.246001
# Breast_EI813          0.0     2.604800   0.084083    0.000000    6.220761
# Breast_PV9            0.0     2.951661   0.203724    0.000000    4.953871
# Breast_KY76           0.0     0.681669   1.280838    0.000000    3.253469
# Breast_EPQV2          0.0     3.353398   0.126857    2.249363    4.996285
#
#               ...  rna_SORBS3  rna_ZNF319  rna_TNFSF9  rna_DSCC1  rna_KCNJ6  \
# Breast_SQ68   ...    5.444250    0.735619    3.384775   1.780470   0.000000
# Breast_EI813  ...    4.977903    0.779594    1.501847   1.510213   0.088314
# Breast_PV9    ...    2.568852    0.403705    0.382281   1.929621   0.000000
# Breast_KY76   ...    0.486446    0.243271    0.748612   3.508708   0.000000
# Breast_EPQV2  ...    3.199105    0.718491    0.773509   1.567253   0.044568
#
#               rna_CRYBG3  rna_RAB11FIP1  rna_SYCE1L  rna_EDEM2  \
# Breast_SQ68     0.383234       0.929657    0.323235   3.361120
# Breast_EI813    0.568509       1.439932    0.000000   2.401581
# Breast_PV9      0.045102       1.801183    0.000000   2.263509
# Breast_KY76     0.868706       1.435175    0.000000   0.654121
# Breast_EPQV2    0.838878       3.258475    0.000000   2.568485
#
#               Gefitinib_response
# Breast_SQ68                    0
# Breast_EI813                   0
# Breast_PV9                     0
# Breast_KY76                    0
# Breast_EPQV2                   0
#
# [5 rows x 837 columns]

# %%
mut_columns = [col for col in Gefitinib_df if col.startswith('mut')]

# %%
mut_columns
# Out:
# ['mut_CHI3L2', 'mut_OR5L2', 'mut_ALMS1', 'mut_XIRP1', 'mut_SCRN3']
