# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/mitomycinTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Mitomycin_response    type  mut_C1orf222  mut_CAMTA1  mut_H6PD  \
# Breast_SQ68                    0  Breast             0           0         0
# Breast_EI813                   0  Breast             0           0         0
# Breast_PV9                     1  Breast             0           0         0
# Breast_KY76                    0  Breast             0           0         0
# Breast_EPQV2                   0  Breast             0           0         0
#
#               mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  mut_CSMD2  ...  \
# Breast_SQ68          0          0           0            1          0  ...
# Breast_EI813         0          0           0            0          0  ...
# Breast_PV9           0          1           0            1          0  ...
# Breast_KY76          0          0           0            0          0  ...
# Breast_EPQV2         1          0           1            0          0  ...
#
#               rna_MAFIP  rna_CD24  rna_HLA-DRB3  rna_LOC389831  rna_MGC70870  \
# Breast_SQ68    1.765641  3.610263      0.000000       0.144895      0.109381
# Breast_EI813   0.683720  1.901263      0.000000       1.973497      0.560144
# Breast_PV9     2.985080  4.125750      0.160901       1.316661      0.265797
# Breast_KY76    0.442882  0.320471      0.077141       3.301013      0.063881
# Breast_EPQV2   3.361561  7.317910      0.071225       2.624524      0.108735
#
#               rna_LOC100233156  rna_LOC389834  rna_LOC283788  rna_RNA5-8S5  \
# Breast_SQ68           0.000000       0.377070       0.743830      7.430427
# Breast_EI813          0.763473       0.508316       1.166169      9.509599
# Breast_PV9            1.167377       1.316250       1.320358      7.672418
# Breast_KY76           0.323250       0.515944       0.272920      4.727648
# Breast_EPQV2          1.402040       1.296005       1.550906     10.491553
#
#               rna_LOC102723780
# Breast_SQ68           0.379076
# Breast_EI813          1.445901
# Breast_PV9            0.230426
# Breast_KY76           0.222489
# Breast_EPQV2          2.474496
#
# [5 rows x 15990 columns]

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Mitomycin_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 892

# %%
Mitomycin_df = df[final_columns]

# %%
# Assuming 'y' is the response column
Mitomycin_df = Mitomycin_df[[col for col in Mitomycin_df.columns if col != 'Mitomycin_response'] + ['Mitomycin_response']]

# %%
Mitomycin_df.head()
# Out:
#               rna_LIN7A  rna_PRMT1  rna_LOC101927811  rna_STRA6  rna_RPTOR  \
# Breast_SQ68    0.000000   5.243791          0.000000   0.402875   1.731348
# Breast_EI813   0.183122   4.926721          0.000000   0.230036   1.399669
# Breast_PV9     2.404527   5.918866          0.000000   0.115601   1.605641
# Breast_KY76    0.000000   2.112764          0.310099   0.000000   0.784719
# Breast_EPQV2   0.000000   4.505262          0.665540   0.070076   1.963382
#
#               rna_NCOR2  rna_NEDD4L  rna_SPANXD  rna_ARRDC2  rna_GIT1  ...  \
# Breast_SQ68    3.017177    0.594821    0.000000    1.265725  3.459432  ...
# Breast_EI813   3.680651    1.838887    0.328066    1.256153  2.129629  ...
# Breast_PV9     4.181293    1.628144    0.000000    2.453942  3.958685  ...
# Breast_KY76    0.808779    3.980482    0.000000    0.352799  0.617868  ...
# Breast_EPQV2   2.976505    2.089796    0.000000    1.607418  3.523938  ...
#
#               rna_SNORA76A  rna_KLHDC3  rna_POLR2C  rna_FAM192A  rna_ANGPT1  \
# Breast_SQ68            0.0    4.123848    3.017227     2.917753    0.000000
# Breast_EI813           0.0    4.023113    2.941854     2.072401    1.994518
# Breast_PV9             0.0    4.583663    3.323177     2.509361    0.000000
# Breast_KY76            0.0    1.757224    2.782291     2.668258    0.106864
# Breast_EPQV2           0.0    4.479703    3.711352     2.819969    0.749702
#
#               rna_OR2A4  rna_FAAP100  rna_PPM1G  rna_MATK  Mitomycin_response
# Breast_SQ68    0.000000     2.115702   4.414643  0.000000                   0
# Breast_EI813   0.154298     1.859985   3.787913  0.246065                   0
# Breast_PV9     0.000000     2.274101   5.194044  3.159366                   1
# Breast_KY76    0.173571     0.294350   4.466412  0.056055                   0
# Breast_EPQV2   0.075084     2.540226   4.125998  0.077149                   0
#
# [5 rows x 892 columns]

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Mitomycin_final.csv', index=False)
