# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/mitomycinFulvestrantTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Mitomycin-Fulvestrant_response    type  mut_C1orf222  \
# Breast_SQ68                                0  Breast             0
# Breast_EI813                               1  Breast             0
# Breast_PV9                                 1  Breast             0
# Breast_KY76                                1  Breast             0
# Breast_EPQV2                               0  Breast             0
#
#               mut_CAMTA1  mut_H6PD  mut_SPEN  mut_HSPG2  mut_ARID1A  \
# Breast_SQ68            0         0         0          0           0
# Breast_EI813           0         0         0          0           0
# Breast_PV9             0         0         0          1           0
# Breast_KY76            0         0         0          0           0
# Breast_EPQV2           0         0         1          0           1
#
#               mut_ZSCAN20  mut_CSMD2  ...  rna_MAFIP  rna_CD24  rna_HLA-DRB3  \
# ...

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Mitomycin-Fulvestrant_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 579

# %%
Mitomycin_Fulvestrant_df = df[final_columns]

# %%
# Assuming 'y' is the response column
Mitomycin_Fulvestrant_df = Mitomycin_Fulvestrant_df[[col for col in Mitomycin_Fulvestrant_df.columns if col != 'Mitomycin-Fulvestrant_response'] + ['Mitomycin-Fulvestrant_response']]

# %%
Mitomycin_Fulvestrant_df.head()
# Out:
#               rna_SDAD1  rna_ZNF445  rna_STX17  rna_PHF7  rna_STRADA  \
# Breast_SQ68    1.906383    0.475247   1.024497  1.043526    2.105668
# Breast_EI813   1.387533    0.839035   0.437635  0.438036    1.327222
# Breast_PV9     2.749757    0.743047   1.278782  0.448587    3.045391
# Breast_KY76    5.321524    0.644476   1.530445  2.355343    1.453149
# Breast_EPQV2   2.751676    0.983900   1.504015  0.600327    2.525954
#
#               rna_ZNRF1  rna_EIF2AK2  rna_PPFIA3  rna_ZNF343  rna_TMEM254  \
# Breast_SQ68    1.582301     2.631593    1.724022    1.019652     1.998604
# Breast_EI813   1.266805     1.580155    0.363374    1.148166     1.470381
# Breast_PV9     4.096220     2.202186    1.717250    1.168270     3.267149
# Breast_KY76    2.537607     2.997179    0.063589    1.227815     2.574969
# Breast_EPQV2   3.304362     2.042728    1.546581    1.126715     3.796110
#
#               ...  rna_ACTBL2  rna_CNIH4  rna_PLSCR1  rna_TYMP  rna_FAM129B  \
# ...

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Mitomycin_Fulvestrant_final.csv', index=False)
