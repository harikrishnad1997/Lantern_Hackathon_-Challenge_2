# %%
import pandas as pd
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         52 mins 49 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.2
# H2O_cluster_version_age:    10 days
# H2O_cluster_name:           H2O_from_python_unknownUser_uvsctq
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    12.01 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  ----------------------------------

# %%
df = h2o.import_file(path="Mitomycin_Fulvestrant_final.csv")
df.head()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# ...

# %%
df.shape
# Out:
# (48, 579)

# %%
y = "Mitomycin-Fulvestrant_response"
x = df.columns
x.remove(y)
len(x)
# Out:
# 578

# %%
df[y] = df[y].asfactor()

# %%
for col in x:
    if 'mut' in col:
        df[col] = df[col].asfactor()

# %%
df["type"] = df["type"].asfactor()

# %%
from h2o.automl import H2OAutoML
aml = H2OAutoML(max_models=100,balance_classes=True, seed=72854874
                # ,include_algos = ["DRF","StackedEnsemble" , "XGBoost"]
               )
aml.train(x=x,y=y, training_frame=df)
# Out:
# AutoML progress: |██
# 08:56:41.808: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 48.0.
#
# █████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_7_20231119_85638_model_8
#
#
# Status of Neuron Layers: predicting Mitomycin-Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 12,082 weights/biases, 217.3 KB, 431 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias              bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  ---------------------  --------------------
# ...

# %%
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# model_id                                                                      auc    logloss     aucpr    mean_per_class_error      rmse        mse
# -----------------------------------------------------------------------  --------  ---------  --------  ----------------------  --------  ---------
# DeepLearning_grid_1_AutoML_7_20231119_85638_model_8                      0.989418   0.172786  0.991911               0.047619   0.233869  0.0546948
# StackedEnsemble_BestOfFamily_1_AutoML_7_20231119_85638                   0.989418   0.128931  0.992292               0.042328   0.205123  0.0420752
# GLM_1_AutoML_7_20231119_85638                                            0.987654   0.145852  0.990166               0.047619   0.217165  0.0471606
# DeepLearning_grid_1_AutoML_7_20231119_85638_model_5                      0.9806     0.752     0.986687               0.0608466  0.27349   0.0747969
# ...

# %%
best_model = aml.get_best_model()
print(best_model)
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_7_20231119_85638_model_8
#
#
# Status of Neuron Layers: predicting Mitomycin-Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 12,082 weights/biases, 217.3 KB, 431 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias              bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  ---------------------  --------------------
#     1        601      Input             5.0
#     2        20       RectifierDropout  30.0       0.0   0.0   0.2151539060000885   0.23027431964874268  0.0         0.0006986599761025348  0.05694977939128876  0.49663933861656373    0.012027077376842499
# ...

# %%
aml.leader
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_7_20231119_85638_model_8
#
#
# Status of Neuron Layers: predicting Mitomycin-Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 12,082 weights/biases, 217.3 KB, 431 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias              bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  ---------------------  --------------------
#     1        601      Input             5.0
#     2        20       RectifierDropout  30.0       0.0   0.0   0.2151539060000885   0.23027431964874268  0.0         0.0006986599761025348  0.05694977939128876  0.49663933861656373    0.012027077376842499
# ...

# %%
h2o.save_model(model=best_model, path="/root/capsule/code/Mitomycin_Fulvestrant", force=True)
# Out:
# '/root/capsule/code/Mitomycin_Fulvestrant/DeepLearning_grid_1_AutoML_7_20231119_85638_model_8'
