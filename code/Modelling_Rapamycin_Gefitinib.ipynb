# %%
import pandas as pd
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321. connected.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         1 hour 0 mins
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.2
# H2O_cluster_version_age:    10 days
# H2O_cluster_name:           H2O_from_python_unknownUser_uvsctq
# H2O_cluster_total_nodes:    1
# H2O_cluster_free_memory:    11.60 Gb
# H2O_cluster_total_cores:    8
# H2O_cluster_allowed_cores:  8
# H2O_cluster_status:         locked, healthy
# H2O_connection_url:         http://localhost:54321
# H2O_connection_proxy:       {"http": null, "https": null}
# H2O_internal_security:      False
# Python_version:             3.10.12 final
# --------------------------  ----------------------------------

# %%
df = h2o.import_file(path="Rapamycin_Gefitinib.csv")
df.head()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# ...

# %%
df.shape
# Out:
# (48, 1354)

# %%
y = "Rapamycin-Gefitinib_response"
x = df.columns
x.remove(y)
len(x)
# Out:
# 1353

# %%
df[y] = df[y].asfactor()

# %%
for col in x:
    if 'mut' in col:
        df[col] = df[col].asfactor()

# %%
df["type"] = df["type"].asfactor()

# %%
from h2o.automl import H2OAutoML
aml = H2OAutoML(max_models=100,balance_classes=True, seed=72854874
                # ,include_algos = ["DRF","StackedEnsemble" , "XGBoost"]
               )
aml.train(x=x,y=y, training_frame=df)
# Out:
# AutoML progress: |█████
# 09:03:31.738: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 48.0.
#
# ██████████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_8_20231119_90318_model_3
#
#
# Status of Neuron Layers: predicting Rapamycin-Gefitinib_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 27,542 weights/biases, 494.2 KB, 550 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate             rate_rms              momentum    mean_weight            weight_rms          mean_bias               bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  --------------------  --------------------  ----------  ---------------------  ------------------  ----------------------  -------------------
# ...

# %%
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# model_id                                                     auc    logloss     aucpr    mean_per_class_error      rmse       mse
# ------------------------------------------------------  --------  ---------  --------  ----------------------  --------  --------
# DeepLearning_grid_1_AutoML_8_20231119_90318_model_3     0.931818   1.54886   0.902692                0.106643  0.322863  0.10424
# DeepLearning_grid_2_AutoML_8_20231119_90318_model_13    0.921329   0.704116  0.925445                0.129371  0.410468  0.168484
# DeepLearning_grid_3_AutoML_8_20231119_90318_model_6     0.911713   0.870799  0.840618                0.125874  0.334031  0.111577
# DeepLearning_grid_1_AutoML_8_20231119_90318_model_7     0.907343   0.894576  0.918017                0.141608  0.362749  0.131587
# DeepLearning_grid_3_AutoML_8_20231119_90318_model_16    0.90035    0.527747  0.876506                0.157343  0.382036  0.145951
# ...

# %%
best_model = aml.get_best_model()
print(best_model)
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_8_20231119_90318_model_3
#
#
# Status of Neuron Layers: predicting Rapamycin-Gefitinib_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 27,542 weights/biases, 494.2 KB, 550 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate             rate_rms              momentum    mean_weight            weight_rms          mean_bias               bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  --------------------  --------------------  ----------  ---------------------  ------------------  ----------------------  -------------------
#     1        1374     Input             20.0
#     2        20       RectifierDropout  50.0       0.0   0.0   0.017684727102741594  0.08514782786369324   0.0         0.0027345162924937855  0.0499173104763031  0.45245151186528865     0.05696330964565277
# ...

# %%
aml.leader
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_1_AutoML_8_20231119_90318_model_3
#
#
# Status of Neuron Layers: predicting Rapamycin-Gefitinib_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 27,542 weights/biases, 494.2 KB, 550 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate             rate_rms              momentum    mean_weight            weight_rms          mean_bias               bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  --------------------  --------------------  ----------  ---------------------  ------------------  ----------------------  -------------------
#     1        1374     Input             20.0
#     2        20       RectifierDropout  50.0       0.0   0.0   0.017684727102741594  0.08514782786369324   0.0         0.0027345162924937855  0.0499173104763031  0.45245151186528865     0.05696330964565277
# ...

# %%
h2o.save_model(model=best_model, path="/root/capsule/code/Rapamycin_Gefitinib", force=True)
# Out:
# '/root/capsule/code/Rapamycin_Gefitinib/DeepLearning_grid_1_AutoML_8_20231119_90318_model_3'
