# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/rapamycinTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Rapamycin_response    type  mut_C1orf222  mut_CAMTA1  mut_H6PD  \
# Breast_SQ68                    1  Breast             0           0         0
# Breast_EI813                   1  Breast             0           0         0
# Breast_PV9                     1  Breast             0           0         0
# Breast_KY76                    0  Breast             0           0         0
# Breast_EPQV2                   1  Breast             0           0         0
#
#               mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  mut_CSMD2  ...  \
# Breast_SQ68          0          0           0            1          0  ...
# Breast_EI813         0          0           0            0          0  ...
# Breast_PV9           0          1           0            1          0  ...
# Breast_KY76          0          0           0            0          0  ...
# Breast_EPQV2         1          0           1            0          0  ...
#
#               rna_MAFIP  rna_CD24  rna_HLA-DRB3  rna_LOC389831  rna_MGC70870  \
# Breast_SQ68    1.765641  3.610263      0.000000       0.144895      0.109381
# Breast_EI813   0.683720  1.901263      0.000000       1.973497      0.560144
# Breast_PV9     2.985080  4.125750      0.160901       1.316661      0.265797
# Breast_KY76    0.442882  0.320471      0.077141       3.301013      0.063881
# Breast_EPQV2   3.361561  7.317910      0.071225       2.624524      0.108735
#
#               rna_LOC100233156  rna_LOC389834  rna_LOC283788  rna_RNA5-8S5  \
# Breast_SQ68           0.000000       0.377070       0.743830      7.430427
# Breast_EI813          0.763473       0.508316       1.166169      9.509599
# Breast_PV9            1.167377       1.316250       1.320358      7.672418
# Breast_KY76           0.323250       0.515944       0.272920      4.727648
# Breast_EPQV2          1.402040       1.296005       1.550906     10.491553
#
#               rna_LOC102723780
# Breast_SQ68           0.379076
# Breast_EI813          1.445901
# Breast_PV9            0.230426
# Breast_KY76           0.222489
# Breast_EPQV2          2.474496
#
# [5 rows x 15990 columns]

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Rapamycin_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 1001

# %%
Rapamycin_df = df[final_columns]

# %%
# Assuming 'y' is the response column
Rapamycin_df  = Rapamycin_df [[col for col in Rapamycin_df .columns if col != 'Rapamycin_response'] + ['Rapamycin_response']]

# %%
Rapamycin_df.head()
# Out:
#               rna_CXCL1  rna_S100P  rna_LMAN1  rna_MRGBP  rna_IRS2  \
# Breast_SQ68    5.901897   1.172084   3.024534   3.908967  0.671033
# Breast_EI813   0.000000   0.000000   3.731466   2.884741  0.127250
# Breast_PV9     0.000000   0.704402   2.741868   4.135568  1.736648
# Breast_KY76    1.779466   0.317697   4.689657   4.420637  3.272677
# Breast_EPQV2   0.141672   3.669548   3.125201   3.635940  0.402080
#
#               rna_CEACAM8  rna_TAGLN2  rna_CEACAM1  rna_SAT1  rna_ITPR2  ...  \
# Breast_SQ68      0.000000    8.151509     0.000000  4.481602   0.418183  ...
# Breast_EI813     0.166385    7.844222     0.129736  3.648281   0.512606  ...
# Breast_PV9       0.000000    6.751089     0.000000  2.549938   0.629843  ...
# Breast_KY76      0.000000    3.140638     0.000000  4.651080   0.935350  ...
# Breast_EPQV2     0.032843    7.853441     0.172999  4.706293   1.151664  ...
#
#               rna_LNPEP  rna_ERV3-1  rna_EME2  rna_CDH13  rna_LINC00634  \
# Breast_SQ68    1.265617    1.107895  0.289165   0.000000       0.444494
# Breast_EI813   0.946925    0.749004  0.410930   3.966726       0.353641
# Breast_PV9     1.796818    2.210096  1.097233   0.151522       0.331202
# Breast_KY76    1.626719    0.239732  0.121297   0.000000       0.080954
# Breast_EPQV2   2.530867    1.188369  0.675799   0.417130       0.261892
#
#               mut_AFF2  rna_ARHGAP27  rna_SLC9A1  rna_IL21R  \
# Breast_SQ68          0      0.000000    2.323589   0.894104
# Breast_EI813         0      0.163454    2.412633   0.485706
# Breast_PV9           0      1.477014    2.448893   0.055100
# Breast_KY76          0      0.374884    0.508627   0.000000
# Breast_EPQV2         0      2.264107    3.182524   0.041257
#
#               Rapamycin_response
# Breast_SQ68                    1
# Breast_EI813                   1
# Breast_PV9                     1
# Breast_KY76                    0
# Breast_EPQV2                   1
#
# [5 rows x 1001 columns]

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Rapamycin_final.csv', index=False)
