# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/shash/Downloads/rapamycinGefitinibTrain.tsv', sep = '\t')

# %%
df.head()
# Out:
#               Rapamycin-Gefitinib_response    type  mut_C1orf222  mut_CAMTA1  \
# Breast_SQ68                              1  Breast             0           0
# Breast_EI813                             0  Breast             0           0
# Breast_PV9                               0  Breast             0           0
# Breast_KY76                              0  Breast             0           0
# Breast_EPQV2                             1  Breast             0           0
#
#               mut_H6PD  mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  \
# Breast_SQ68          0         0          0           0            1
# Breast_EI813         0         0          0           0            0
# Breast_PV9           0         0          1           0            1
# Breast_KY76          0         0          0           0            0
# Breast_EPQV2         0         1          0           1            0
#
#               mut_CSMD2  ...  rna_MAFIP  rna_CD24  rna_HLA-DRB3  \
# Breast_SQ68           0  ...   1.765641  3.610263      0.000000
# Breast_EI813          0  ...   0.683720  1.901263      0.000000
# Breast_PV9            0  ...   2.985080  4.125750      0.160901
# Breast_KY76           0  ...   0.442882  0.320471      0.077141
# Breast_EPQV2          0  ...   3.361561  7.317910      0.071225
#
#               rna_LOC389831  rna_MGC70870  rna_LOC100233156  rna_LOC389834  \
# Breast_SQ68        0.144895      0.109381          0.000000       0.377070
# Breast_EI813       1.973497      0.560144          0.763473       0.508316
# Breast_PV9         1.316661      0.265797          1.167377       1.316250
# Breast_KY76        3.301013      0.063881          0.323250       0.515944
# Breast_EPQV2       2.624524      0.108735          1.402040       1.296005
#
#               rna_LOC283788  rna_RNA5-8S5  rna_LOC102723780
# Breast_SQ68        0.743830      7.430427          0.379076
# Breast_EI813       1.166169      9.509599          1.445901
# Breast_PV9         1.320358      7.672418          0.230426
# Breast_KY76        0.272920      4.727648          0.222489
# Breast_EPQV2       1.550906     10.491553          2.474496
#
# [5 rows x 15990 columns]

# %%
column_names = df.columns

# %%
mut_columns = [col for col in column_names if col.startswith('mut')]
len(mut_columns)
mut_columns[0:5]
# Out:
# ['mut_C1orf222', 'mut_CAMTA1', 'mut_H6PD', 'mut_SPEN', 'mut_HSPG2']

# %%
rna_columns = [col for col in column_names if col.startswith('rna')]
len(rna_columns)
# Out:
# 15774

# %%
from FS_Class import FeatureSelectionPipeline

# %%
feature_selector = FeatureSelectionPipeline(df, rna_columns, mut_columns, 'Rapamycin-Gefitinib_response')

# %%
rna_var_columns = feature_selector.create_rna_pipeline()

# %%
anova_test_result = feature_selector.perform_anova_test(rna_var_columns)

# %%
chi_test_result = feature_selector.perform_chi_square_test()

# %%
final_columns = feature_selector.get_final_columns(anova_test_result, chi_test_result)

# %%
print(len(final_columns))
# Out:
# 1354

# %%
Rapamycin_Gefitinib_df = df[final_columns]

# %%
# Assuming 'y' is the response column
Rapamycin_Gefitinib_df = Rapamycin_Gefitinib_df[[col for col in Rapamycin_Gefitinib_df.columns if col != 'Rapamycin-Gefitinib_response'] + ['Rapamycin-Gefitinib_response']]

# %%
Rapamycin_Gefitinib_df.head()
# Out:
#               rna_ATPAF1  rna_YTHDF3  rna_USP47  rna_EIF3M  rna_DNAJA1  \
# Breast_SQ68     2.582741    3.200167   1.321160   3.270722    5.293286
# Breast_EI813    2.561177    2.366884   1.433697   2.768129    3.938211
# Breast_PV9      3.725927    2.821949   1.458088   3.598270    5.429927
# Breast_KY76     4.082251    3.107748   3.822037   7.869606    7.235019
# Breast_EPQV2    4.044840    3.532255   1.999589   5.535571    4.585065
#
#               rna_C5orf30  rna_NRCAM  rna_ATP6V1B1  rna_DYRK4  rna_GUF1  ...  \
# Breast_SQ68      2.216166   0.000000      0.000000   2.336732  1.210227  ...
# Breast_EI813     1.690319   0.270192      0.193441   2.492484  0.979877  ...
# Breast_PV9       2.272008   1.042539      0.620747   3.000334  1.772114  ...
# Breast_KY76      1.870811   0.141840      0.113932   3.447850  3.163057  ...
# Breast_EPQV2     1.529701   0.130073      0.582027   2.465674  1.798461  ...
#
#               rna_MOB1A  rna_DDHD1  rna_STK38L  rna_TMEM33  rna_MACROD2  \
# Breast_SQ68    2.009684   0.537139    0.662118    1.480224     0.000000
# Breast_EI813   2.749551   0.450068    1.395847    0.884348     0.146939
# Breast_PV9     3.542828   0.838601    0.490729    1.680603     0.237233
# Breast_KY76    5.187380   1.736497    1.236615    2.471044     0.000000
# Breast_EPQV2   3.568263   0.701743    0.654427    1.819296     0.196018
#
#               rna_NPM1  rna_HEXIM2  rna_LYAR  rna_RPS20  \
# Breast_SQ68   6.007012    1.844490  2.823495   7.893975
# Breast_EI813  5.155943    0.728269  1.655924   7.205490
# Breast_PV9    7.349533    2.013559  3.335625   7.223896
# Breast_KY76   9.978239    0.633749  6.135475   9.857742
# Breast_EPQV2  7.802303    2.343925  2.954734   8.916127
#
#               Rapamycin-Gefitinib_response
# Breast_SQ68                              1
# Breast_EI813                             0
# Breast_PV9                               0
# Breast_KY76                              0
# Breast_EPQV2                             1
#
# [5 rows x 1354 columns]

# %%
# Assuming 'df' is your DataFrame
df.to_csv('Rapamycin_Gefitinib.csv', index=False)
