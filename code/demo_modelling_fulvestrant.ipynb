# %%
import pandas as pd
raw = pd.read_csv("/root/capsule/data/challenge2_files/fulvestrantTrain.tsv",sep='\t')
raw.head()
# Out:
#               Fulvestrant_response    type  mut_C1orf222  mut_CAMTA1  \
# Breast_SQ68                      1  Breast             0           0
# Breast_EI813                     0  Breast             0           0
# Breast_PV9                       1  Breast             0           0
# Breast_KY76                      0  Breast             0           0
# Breast_EPQV2                     1  Breast             0           0
#
#               mut_H6PD  mut_SPEN  mut_HSPG2  mut_ARID1A  mut_ZSCAN20  \
# Breast_SQ68          0         0          0           0            1
# Breast_EI813         0         0          0           0            0
# Breast_PV9           0         0          1           0            1
# Breast_KY76          0         0          0           0            0
# Breast_EPQV2         0         1          0           1            0
#
#               mut_CSMD2  ...  rna_MAFIP  rna_CD24  rna_HLA-DRB3  \
# Breast_SQ68           0  ...   1.765641  3.610263      0.000000
# ...

# %%
import h2o
h2o.init()
# Out:
# Checking whether there is an H2O instance running at http://localhost:54321..... not found.
# Attempting to start a local H2O server...
#   Java Version: openjdk version "1.8.0_382"; OpenJDK Runtime Environment (Zulu 8.72.0.17-CA-linux64) (build 1.8.0_382-b05); OpenJDK 64-Bit Server VM (Zulu 8.72.0.17-CA-linux64) (build 25.382-b05, mixed mode)
#   Starting server from /opt/conda/lib/python3.10/site-packages/h2o/backend/bin/h2o.jar
#   Ice root: /tmp/tmpj1h_jqlu
#   JVM stdout: /tmp/tmpj1h_jqlu/h2o_unknownUser_started_from_python.out
#   JVM stderr: /tmp/tmpj1h_jqlu/h2o_unknownUser_started_from_python.err
#   Server is running at http://127.0.0.1:54321
# Connecting to H2O server at http://127.0.0.1:54321 ... successful.
# --------------------------  ----------------------------------
# H2O_cluster_uptime:         01 secs
# H2O_cluster_timezone:       Etc/UTC
# H2O_data_parsing_timezone:  UTC
# H2O_cluster_version:        3.44.0.2
# H2O_cluster_version_age:    9 days
# ...

# %%
columns = pd.read_csv("/root/capsule/code/final_col_fulvestrant.csv",index_col=0)
col = list(set(columns["features"]))
len(col)
# Out:
# 1602

# %%
df = h2o.H2OFrame(raw[col])
df.describe()
# Out:
# Parse progress: |████████████████████████████████████████████████████████████████| (done) 100%
# Rows:48
# Cols:1602
# ...

# %%
y = "Fulvestrant_response"
x = df.columns
x.remove(y)
len(x)
# Out:
# 1601

# %%
df[y] = df[y].asfactor()

# %%
for col in x:
    if 'mut' in col:
        df[col] = df[col].asfactor()

# %%
df["type"] = df["type"].asfactor()

# %%
c=0
for col in df.types:
    if 'rna' in col:
        print(df[col].types)
        c+=1
        if c>10:
            break
# Out:
# {'rna_SPTBN1': 'real'}
# {'rna_HEATR6': 'real'}
# {'rna_EMC3-AS1': 'real'}
# {'rna_CASKIN1': 'real'}
# {'rna_RTN3': 'real'}
# {'rna_FBXL15': 'real'}
# {'rna_MFGE8': 'real'}
# {'rna_PTGR2': 'real'}
# {'rna_GBAT2': 'real'}
# {'rna_MTRNR2L4': 'real'}
# {'rna_SLC4A5': 'real'}

# %%
df.head()
# Out:
#   rna_SPTBN1    rna_HEATR6    rna_EMC3-AS1    rna_CASKIN1    rna_RTN3    rna_FBXL15    rna_MFGE8    rna_PTGR2    rna_GBAT2    rna_MTRNR2L4    rna_SLC4A5    rna_CRNDE    rna_RNF32    rna_VASH2    rna_ROCK2    rna_MGLL    rna_TMEM61    rna_AKT3    rna_VPS45    rna_NEBL    rna_OCLN    rna_ZNF830    rna_RPL10    rna_LRTOMT    rna_SULT4A1    rna_TIMM8B    rna_MRPS24    rna_TMEM203    rna_ADCY3    rna_DUS4L    rna_DOCK10    rna_CRLF1    rna_CEP85L    rna_GALNT2    rna_LRRK1    rna_NDUFS7    rna_ZNF8    rna_FNDC3B    rna_RPL13    rna_NCK1-AS1    rna_ZNF793-AS1    mut_CIT    rna_PLD6    rna_ZDHHC23    rna_LPPR3    rna_HBA1    rna_OSR2    rna_BTF3L4    rna_INPP5J    rna_SNHG7    rna_LLGL1    rna_ANKRD34B    rna_CASZ1    rna_SLC29A2    rna_LOC100505938    rna_BACE2    rna_COA7    rna_SLC25A33    rna_KIRREL    rna_CCDC88C    rna_FAAH    rna_MRRF    rna_LINC01117    rna_ZG16B    rna_MKNK1    rna_ZNF525    rna_SUCLG2-AS1    rna_LAMC1    rna_DPRXP4    rna_ZNF433    rna_UBE2Q1-AS1    rna_PRSS23    
# ...

# %%
from h2o.automl import H2OAutoML

# %%
aml = H2OAutoML(max_models=100,balance_classes=True, seed=72854874
                # ,include_algos = ["DRF","StackedEnsemble" , "XGBoost"]
               )
aml.train(x=x,y=y, training_frame=df)
# Out:
# AutoML progress: |███
# 08:40:32.521: _min_rows param, The dataset size is too small to split for min_rows=100.0: must have at least 200.0 (weighted) rows, but have only 48.0.
#
# ████████████████████████████████████████████████████████████| (done) 100%
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_2_AutoML_2_20231118_84027_model_3
#
#
# Status of Neuron Layers: predicting Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 32,922 weights/biases, 591.0 KB, 29,600 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias             bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  --------------------  -------------------
# ...

# %%
lb = aml.leaderboard
lb.head(rows=lb.nrows)
# Out:
# model_id                                                     auc    logloss     aucpr    mean_per_class_error      rmse        mse
# ------------------------------------------------------  --------  ---------  --------  ----------------------  --------  ---------
# DeepLearning_grid_2_AutoML_2_20231118_84027_model_3     0.9625     0.93195   0.768404                  0.1375  0.290534  0.0844102
# DeepLearning_grid_2_AutoML_2_20231118_84027_model_4     0.94375    1.02217   0.814444                  0.15    0.416396  0.173385
# StackedEnsemble_BestOfFamily_1_AutoML_2_20231118_84027  0.942187   0.225982  0.722445                  0.1375  0.260697  0.067963
# DeepLearning_grid_1_AutoML_2_20231118_84027_model_5     0.9375     1.43451   0.765918                  0.1375  0.283429  0.0803322
# DeepLearning_grid_2_AutoML_2_20231118_84027_model_8     0.934375   2.05934   0.752049                  0.1375  0.38217   0.146054
# ...

# %%
best_model = aml.get_best_model()
print(best_model)
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_2_AutoML_2_20231118_84027_model_3
#
#
# Status of Neuron Layers: predicting Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 32,922 weights/biases, 591.0 KB, 29,600 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias             bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  --------------------  -------------------
#     1        1622     Input             20.0
#     2        20       RectifierDropout  50.0       0.0   0.0   0.5636312759259162   0.3659203052520752   0.0         -0.007712233886161224  0.07587021589279175  0.5172775908139915    0.23531991243362427
# ...

# %%
aml.leader
# Out:
# Model Details
# ...
# H2ODeepLearningEstimator : Deep Learning
# Model Key: DeepLearning_grid_2_AutoML_2_20231118_84027_model_3
#
#
# Status of Neuron Layers: predicting Fulvestrant_response, 2-class classification, bernoulli distribution, CrossEntropy loss, 32,922 weights/biases, 591.0 KB, 29,600 training samples, mini-batch size 1
#     layer    units    type              dropout    l1    l2    mean_rate            rate_rms             momentum    mean_weight            weight_rms           mean_bias             bias_rms
# --  -------  -------  ----------------  ---------  ----  ----  -------------------  -------------------  ----------  ---------------------  -------------------  --------------------  -------------------
#     1        1622     Input             20.0
#     2        20       RectifierDropout  50.0       0.0   0.0   0.5636312759259162   0.3659203052520752   0.0         -0.007712233886161224  0.07587021589279175  0.5172775908139915    0.23531991243362427
# ...

# %%
best_model
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 best_model
#
# NameError: name 'best_model' is not defined
